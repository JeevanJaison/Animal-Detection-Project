# %%
import os
import cv2
import subprocess

filename = '/Users/mymac/AnimalDetection/elephant.mp4'

def get_frame_types(video_fn):
    command = 'ffprobe -v error -show_entries frame=pict_type -of default=noprint_wrappers=1'.split()
    out = subprocess.check_output(command + [video_fn]).decode()
    frame_types = out.replace('pict_type=','').split()
    return zip(range(len(frame_types)), frame_types)

def save_i_keyframes(video_fn):
    frame_types = get_frame_types(video_fn)
    i_frames = [x[0] for x in frame_types if x[1]=='I']
    if i_frames:
        basename = os.path.splitext(os.path.basename(video_fn))[0]
        cap = cv2.VideoCapture(video_fn)
        for frame_no in i_frames:
            cap.set(cv2.CAP_PROP_POS_FRAMES, frame_no)
            ret, frame = cap.read()
            outname = basename+'i_frame'+str(frame_no)+'.jpg'
            cv2.imwrite(outname, frame)
            print ('Saved: '+outname)
        cap.release()
    else:
        print ('No I-frames in '+video_fn)
save_i_keyframes(filename)
# Out:
# Saved: elephanti_frame0.jpg
# Saved: elephanti_frame2.jpg
# Saved: elephanti_frame160.jpg
# Saved: elephanti_frame320.jpg
# Saved: elephanti_frame480.jpg
# Saved: elephanti_frame640.jpg
# Saved: elephanti_frame800.jpg
# Saved: elephanti_frame905.jpg
# Saved: elephanti_frame960.jpg
# Saved: elephanti_frame1048.jpg
# Saved: elephanti_frame1120.jpg
# Saved: elephanti_frame1243.jpg
# Saved: elephanti_frame1280.jpg
# Saved: elephanti_frame1440.jpg
# Saved: elephanti_frame1600.jpg
# Saved: elephanti_frame1760.jpg
# Saved: elephanti_frame1920.jpg
# Saved: elephanti_frame2080.jpg
# Saved: elephanti_frame2240.jpg
# Saved: elephanti_frame2400.jpg
# Saved: elephanti_frame2560.jpg
# Saved: elephanti_frame2720.jpg
# Saved: elephanti_frame2880.jpg
# Saved: elephanti_frame3040.jpg
# Saved: elephanti_frame3200.jpg
# Saved: elephanti_frame3360.jpg
# Saved: elephanti_frame3520.jpg
# Saved: elephanti_frame3680.jpg
# Saved: elephanti_frame3840.jpg
# Saved: elephanti_frame4000.jpg
# Saved: elephanti_frame4160.jpg
# Saved: elephanti_frame4320.jpg
# Saved: elephanti_frame4480.jpg
# Saved: elephanti_frame4497.jpg
# Saved: elephanti_frame4640.jpg
# Saved: elephanti_frame4655.jpg
# Saved: elephanti_frame4728.jpg
# Saved: elephanti_frame4800.jpg
# Saved: elephanti_frame4960.jpg
# Saved: elephanti_frame5120.jpg
# Saved: elephanti_frame5263.jpg
# Saved: elephanti_frame5280.jpg
# Saved: elephanti_frame5440.jpg
# Saved: elephanti_frame5600.jpg
# Saved: elephanti_frame5760.jpg
# Saved: elephanti_frame5920.jpg
# Saved: elephanti_frame6080.jpg
# Saved: elephanti_frame6240.jpg
# Saved: elephanti_frame6400.jpg
# Saved: elephanti_frame6560.jpg
# Saved: elephanti_frame6720.jpg
# Saved: elephanti_frame6880.jpg
# Saved: elephanti_frame7040.jpg
# Saved: elephanti_frame7200.jpg
# Saved: elephanti_frame7360.jpg
# Saved: elephanti_frame7520.jpg
# Saved: elephanti_frame7680.jpg
# Saved: elephanti_frame7720.jpg
# Saved: elephanti_frame7840.jpg
# Saved: elephanti_frame8000.jpg
# Saved: elephanti_frame8160.jpg
# Saved: elephanti_frame8320.jpg
# Saved: elephanti_frame8480.jpg
# Saved: elephanti_frame8613.jpg
# Saved: elephanti_frame8640.jpg
# Saved: elephanti_frame8800.jpg
# Saved: elephanti_frame8960.jpg
# Saved: elephanti_frame9120.jpg
# Saved: elephanti_frame9280.jpg
# Saved: elephanti_frame9440.jpg
# Saved: elephanti_frame9508.jpg
# Saved: elephanti_frame9600.jpg
# Saved: elephanti_frame9760.jpg
# Saved: elephanti_frame9920.jpg
# Saved: elephanti_frame10080.jpg
# Saved: elephanti_frame10240.jpg
# Saved: elephanti_frame10400.jpg
# Saved: elephanti_frame10560.jpg
# Saved: elephanti_frame10720.jpg
# Saved: elephanti_frame10880.jpg
# Saved: elephanti_frame11040.jpg
# Saved: elephanti_frame11200.jpg
# Saved: elephanti_frame11360.jpg
# Saved: elephanti_frame11520.jpg
# Saved: elephanti_frame11680.jpg
